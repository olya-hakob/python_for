# %% [markdown]
# Նախորդ դասի ընթացքում սովորեցինք թարմացնել փոփոխականի արժեքը՝ հին աշխատավարձի հիման վրա նորը հաշվելով՝
#
# new_salary = old_salary+(old_salary*10)/100 # նոր աշխատավարձ
#
# Ամեն անգամ նույն արտահայտությունը տպելը և՛ ձանձրալի է, և՛ կարող է չնախատեսված սխալների հանգեցնել անուշադրության դեպքում։ Նման խնդիրներից խուսափելու համար կարող ենք օգտագործել ֆունկցիաներ։

# %%
def salary_update(old_salary,raise_percentage):
    return old_salary+(old_salary*raise_percentage)/100
new_salary = salary_update(100,10)
print(new_salary)
# Out:
# 110.0

# %% [markdown]
# Կարող ենք գրել նաև ֆունկցիա, որը կհաշվի տվյալ list-ի միջին արժեքը՝

# %%
def mean(x):
    x_sum = 0
    for item in x:
        x_sum = x_sum+item
#       x_sum += item
    return x_sum/len(x)

# %%
def mean_shorter(x):
    return sum(x)/len(x)

# %%
currency = '$'
old_salaries = [100,120,140,150,160,500,900,1500]
low_salaries = [] # դատարկ list որտեղ պահպանելու ենք ցածր աշխատավարձերը
middle_salaries = [] # դատարկ list որտեղ պահպանելու ենք միջին աշխատավարձերը
high_salaries = [] # դատարկ list որտեղ պահպանելու ենք բարձր աշխատավարձերը
for salary in old_salaries: 
    if salary < 500: 
        low_salaries.append(salary_update(salary,20)) #append նշանակում է կցել, նոր արժեքը կցվում է հատկացված list-ին
    elif 500<salary<1000:
        middle_salaries.append(salary_update(salary,10))
    else:
        high_salaries.append(salary_update(salary,5))
print(f'Ցածր աշխատավարձով աշխատողների թարմացված աշխատավարձի միջինը {mean(low_salaries)}{currency} է')
print(f'Ցածր աշխատավարձով աշխատողների թարմացված աշխատավարձի միջինը է {mean(middle_salaries)}{currency} է')
print(f'Ցածր աշխատավարձով աշխատողների թարմացված աշխատավարձի միջինը է {mean(high_salaries)}{currency} է')
# Out:
# Ցածր աշխատավարձով աշխատողների թարմացված աշխատավարձի միջինը 160.8$ է
# Ցածր աշխատավարձով աշխատողների թարմացված աշխատավարձի միջինը է 990.0$ է
# Ցածր աշխատավարձով աշխատողների թարմացված աշխատավարձի միջինը է 1050.0$ է

# %% [markdown]
# List indexing examples!

# %%
# Առաջադրանք՝ գրել ֆունկցիա որը կհաշվի տրված list-ի մեդիանը
# Ի՞նչ է մեդիանը 
# Ինչպե՞ս հաշվել՝ գրել քայլերը
# Իմպլեմենտացիան Python-ում

# 1. sort the list --> sorted(list) or list.sort()
# 2. check if odd or even --> len(list) % 2
# 3. if odd --> pick the middle one: 
# 4. if even -->  pick the middle one and the one before

# %% [markdown]
# ![median-in-Python-1024x457.png](attachment:median-in-Python-1024x457.png)

# %%
# Ուսումնասիրել հետևյալ կոդն ու նշումների միջոցով բացատրել, թե ինչ է այն անում --> մոդի հաշվարկը
